# %%
# !python /data_perm/F5-TTS_custom/src/f5_tts/infer/infer_cli.py \
    --model "F5-TTS" \
    --gen_text "Merhabalar arkadaşlar, monora podcastin yeni bölümüne hoşgeldiniz, benim adım kaan" \
    --output_dir "/data_perm/" \
    --output_file "finetuned_model_no_reference.wav" \
    --ckpt_file "/data_perm/F5-TTS_custom/ckpts/turkish/model_last.pt"
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.683 seconds.
# Prefix dict has been built successfully.
# Word segmentation module jieba initialized.
#
# Download Vocos from huggingface charactr/vocos-mel-24khz
# Using F5-TTS...
#
# vocab :  /data_perm/F5-TTS_custom/src/f5_tts/infer/examples/vocab.txt
# token :  custom
# model :  /data_perm/F5-TTS_custom/ckpts/turkish/model_last.pt
#
# Voice: main
# ref_audio  /data_perm/F5-TTS_custom/src/f5_tts/infer/examples/basic/basic_ref_en.wav
# Converting audio...
# Using custom reference text...
#
# ref_text   Some call me nature, others call me mother nature.
# ref_audio_ /tmp/tmpbug7npkh.wav
#
#
# No voice tag found, using main.
# Voice: main
# gen_text 0 Merhabalar arkadaşlar, monora podcastin yeni bölümüne hoşgeldiniz, benim adım kaan
#
#
# Generating audio in 1 batches...
# 100%|█████████████████████████████████████████████| 1/1 [00:03<00:00,  3.11s/it]
# ...

# %%
from IPython.display import Audio, display

display(Audio("/data_perm/finetuned_model_no_reference.wav", autoplay=False))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
